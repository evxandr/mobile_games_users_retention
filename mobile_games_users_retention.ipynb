# %% [markdown]
# <H2>Постановка задачи</H2>
# <ul>
#     <li>Есть данные компании, которая разрабатывает мобильные игры. Необходимо написать функцию, которая будет считать retention игроков (по дням от даты регистрации игрока).</li>
# </ul>
#
#
# <H4>Сведения о таблицах</H4>
# <ul>
#     <li>reg_data.csv – данные о времени регистрации</li>
#     <li>auth_data.csv – данные о времени захода пользователей в игру</li>
# </ul>

# %%
#загружаем библиотеки
import pandas as pd
from datetime import timedelta

# %%
#загружаем таблицы в переменные
df_auth_data = pd.read_csv('auth_data.csv', sep=';')
df_reg_data = pd.read_csv('reg_data.csv', sep=';')

# %%
#Функция для проверки значений таблицы
def check_df_values(df, df_name):
    df_info = pd.DataFrame(columns= ['',
                                     'Записей',
                                     'Уникальных',
                                     'Дублей',
                                     'NaN',
                                     'не NaN',
                                     'Min',
                                     'Max',
                                     'Тип'],
                              data=[[f'Сведения о "{df_name}"',
                                     df.shape[0],
                                     df.nunique().sum(),
                                     df.duplicated().sum(),
                                     df.isna().sum().sum(),
                                     df.notna().sum().sum(),
                                     '',
                                     '',
                                     '']])
    for col in df.columns:
        df_info = pd.concat([df_info, 
              pd.DataFrame(columns= ['',
                                     'Записей',
                                     'Уникальных',
                                     'Дублей',
                                     'NaN',
                                     'не NaN',
                                     'Min',
                                     'Max',
                                     'Тип'],
                              data=[[f'Колонка "{col}"', 
                                     df[col].shape[0], 
                                     df[col].nunique(),
                                     df[col].duplicated().sum(),
                                     df[col].isna().sum(),
                                     df[col].notna().sum(),
                                     df[col].min(),
                                     df[col].max(),
                                     df[col].dtype]])],
                              ignore_index=True)
    return df_info

# %%
check_df_values(df_auth_data, 'df_auth_data')
# Out:
#                               Записей  Уникальных   Дублей  NaN    не NaN  \
# 0  Сведения о "df_auth_data"  9601013    10180915        0    0  19202026
# 1          Колонка "auth_ts"  9601013     9180915   420098    0   9601013
# 2              Колонка "uid"  9601013     1000000  8601013    0   9601013
#
#          Min         Max    Тип
# 0
# 1  911382223  1600874244  int64
# 2          1     1110622  int64

# %%
check_df_values(df_reg_data, 'df_reg_data')
# Out:
#                              Записей  Уникальных  Дублей  NaN   не NaN  \
# 0  Сведения о "df_reg_data"  1000000     2000000       0    0  2000000
# 1          Колонка "reg_ts"  1000000     1000000       0    0  1000000
# 2             Колонка "uid"  1000000     1000000       0    0  1000000
#
#          Min         Max    Тип
# 0
# 1  911382223  1600874244  int64
# 2          1     1110622  int64

# %%
df_auth_data
# Out:
#             auth_ts      uid
# 0         911382223        1
# 1         932683089        2
# 2         932921206        2
# 3         933393015        2
# 4         933875379        2
# ...             ...      ...
# 9601008  1600874034  1110618
# 9601009  1600874086  1110619
# 9601010  1600874139  1110620
# 9601011  1600874191  1110621
# 9601012  1600874244  1110622
#
# [9601013 rows x 2 columns]

# %%
df_reg_data
# Out:
#             reg_ts      uid
# 0        911382223        1
# 1        932683089        2
# 2        947802447        3
# 3        959523541        4
# 4        969103313        5
# ...            ...      ...
# 999995  1600874034  1110618
# 999996  1600874086  1110619
# 999997  1600874139  1110620
# 999998  1600874191  1110621
# 999999  1600874244  1110622
#
# [1000000 rows x 2 columns]

# %% [markdown]
# <li>Колонки auth_ts и reg_ts должны иметь тип даты. Поэтому преобразуем колонки в нужный тип данных. А также избавимся от значений времени (часы, минуты, секунды), чтобы мы могли строить когорту по дням.

# %%
#Замечание по поводу применения pd.to_datetime(pd.to_datetime(...))
#вложенный метод "to_datetime" приводит к типу object, 
#а второй метод "to_datetime" уже приводит к типу "datetime64"
df_auth_data['auth_ts'] = pd.to_datetime(pd.to_datetime(df_auth_data['auth_ts'], unit='s').dt.date)
df_reg_data['reg_ts'] = pd.to_datetime(pd.to_datetime(df_reg_data['reg_ts'], unit='s').dt.date)

# %%
check_df_values(df_auth_data, 'df_auth_data')
# Out:
#                               Записей  Уникальных   Дублей  NaN    не NaN  \
# 0  Сведения о "df_auth_data"  9601013     1006169        0    0  19202026
# 1          Колонка "auth_ts"  9601013        6169  9594844    0   9601013
# 2              Колонка "uid"  9601013     1000000  8601013    0   9601013
#
#                    Min                  Max             Тип
# 0
# 1  1998-11-18 00:00:00  2020-09-23 00:00:00  datetime64[ns]
# 2                    1              1110622           int64

# %%
check_df_values(df_reg_data, 'df_reg_data')
# Out:
#                              Записей  Уникальных  Дублей  NaN   не NaN  \
# 0  Сведения о "df_reg_data"  1000000     1005110       0    0  2000000
# 1          Колонка "reg_ts"  1000000        5110  994890    0  1000000
# 2             Колонка "uid"  1000000     1000000       0    0  1000000
#
#                    Min                  Max             Тип
# 0
# 1  1998-11-18 00:00:00  2020-09-23 00:00:00  datetime64[ns]
# 2                    1              1110622           int64

# %% [markdown]
# <H4>Анализ данных после преобразования</H4>
# <ul>
#     <li>Убрав время у колонок auth_ts и reg_ts видим, что таблицы не имеют задублированных строк. Следовательно, каждая строка таблиц - это уникальная комбинация значений даты и ИД пользователя.</li>
#     <li>Таблицы не имеют пропусков в данных (NaN = 0).</li>
#     <li>В таблице "auth_data" 6169 уникальных дат с 1998 по 2020 годы.</li>
#     <li>В таблице "reg_data" 5110 уникальных дат с 1998 по 2020 годы.</li>
# </ul>

# %% [markdown]
# <H4>Объединим таблицы вместе</H4>

# %%
df_merged = df_reg_data.merge(df_auth_data, on='uid', how='left')

# %%
check_df_values(df_merged, 'df_merged')
# Out:
#                            Записей  Уникальных   Дублей  NaN    не NaN  \
# 0  Сведения о "df_merged"  9601013     1011279        0    0  28803039
# 1        Колонка "reg_ts"  9601013        5110  9595903    0   9601013
# 2           Колонка "uid"  9601013     1000000  8601013    0   9601013
# 3       Колонка "auth_ts"  9601013        6169  9594844    0   9601013
#
#                    Min                  Max             Тип
# 0
# 1  1998-11-18 00:00:00  2020-09-23 00:00:00  datetime64[ns]
# 2                    1              1110622           int64
# 3  1998-11-18 00:00:00  2020-09-23 00:00:00  datetime64[ns]

# %%
df_merged.head()
# Out:
#       reg_ts  uid    auth_ts
# 0 1998-11-18    1 1998-11-18
# 1 1999-07-22    2 1999-07-22
# 2 1999-07-22    2 1999-07-25
# 3 1999-07-22    2 1999-07-31
# 4 1999-07-22    2 1999-08-05

# %%
#создадим колонку с разницей в днях между датой регистрации и датой авторизации
df_merged['days_diff'] = (df_merged["auth_ts"] - df_merged["reg_ts"]).dt.days

# %%
df_merged
# Out:
#             reg_ts      uid    auth_ts  days_diff
# 0       1998-11-18        1 1998-11-18          0
# 1       1999-07-22        2 1999-07-22          0
# 2       1999-07-22        2 1999-07-25          3
# 3       1999-07-22        2 1999-07-31          9
# 4       1999-07-22        2 1999-08-05         14
# ...            ...      ...        ...        ...
# 9601008 2020-09-23  1110618 2020-09-23          0
# 9601009 2020-09-23  1110619 2020-09-23          0
# 9601010 2020-09-23  1110620 2020-09-23          0
# 9601011 2020-09-23  1110621 2020-09-23          0
# 9601012 2020-09-23  1110622 2020-09-23          0
#
# [9601013 rows x 4 columns]

# %%
#сгруппируем ДФ по дате регистрации и разнице дней, чтобы сосчитать количество пользователей
cohort_df = df_merged.groupby(['reg_ts', 'days_diff'], as_index=False)\
                    .agg({'uid' : 'nunique'})\
                    .rename(columns={'uid' : 'uid_count', 'reg_ts' : 'reg_date'})
cohort_df
# Out:
#           reg_date  days_diff  uid_count
# 0       1998-11-18          0          1
# 1       1999-07-22          0          1
# 2       1999-07-22          3          1
# 3       1999-07-22          9          1
# 4       1999-07-22         14          1
# ...            ...        ...        ...
# 2716223 2020-09-21          1         31
# 2716224 2020-09-21          2         49
# 2716225 2020-09-22          0       1641
# 2716226 2020-09-22          1         14
# 2716227 2020-09-23          0       1048
#
# [2716228 rows x 3 columns]

# %%
#создадим колонку размера когорты из нулевого дня, чтобы высчитать процент по каждому дню
cohort_group_size = cohort_df.query('days_diff == 0')\
                                .rename(columns={'uid_count' : 'uid_cohort_size'})\
                                [['reg_date', 'uid_cohort_size']]

#присоединяем колонку размера когорты к таблице
cohort_df = cohort_df.merge(cohort_group_size, how='inner', on='reg_date')

#считаем процент вернувшихся пользователей
cohort_df['uid_retention_percent'] = cohort_df.uid_count / cohort_df.uid_cohort_size

cohort_df
# Out:
#           reg_date  days_diff  uid_count  uid_cohort_size  \
# 0       1998-11-18          0          1                1
# 1       1999-07-22          0          1                1
# 2       1999-07-22          3          1                1
# 3       1999-07-22          9          1                1
# 4       1999-07-22         14          1                1
# ...            ...        ...        ...              ...
# 2716223 2020-09-21          1         31             1638
# 2716224 2020-09-21          2         49             1638
# 2716225 2020-09-22          0       1641             1641
# 2716226 2020-09-22          1         14             1641
# 2716227 2020-09-23          0       1048             1048
#
#          uid_retention_percent
# 0                     1.000000
# 1                     1.000000
# 2                     1.000000
# 3                     1.000000
# 4                     1.000000
# ...                        ...
# 2716223               0.018926
# 2716224               0.029915
# 2716225               1.000000
# 2716226               0.008531
# 2716227               1.000000
#
# [2716228 rows x 5 columns]

# %%
#устанваливаем период, за который планируем выгружать когорту
cohort_period = cohort_df.reg_date.max() - timedelta(days=300)

# %%
#преобразуем таблицу в вид сводной таблицы
final_cohort = cohort_df.query('reg_date >= @cohort_period')
final_cohort = final_cohort.assign(reg_date = final_cohort.reg_date.dt.strftime('%Y-%m-%d'))
final_cohort = final_cohort.pivot(index=['reg_date', 'uid_cohort_size'], columns = 'days_diff', values = 'uid_retention_percent')
final_cohort
# Out:
# days_diff                   0         1         2         3         4    \
# reg_date   uid_cohort_size
# 2019-11-28 1004             1.0  0.011952  0.040837  0.040837  0.044821
# 2019-11-29 1005             1.0  0.025871  0.045771  0.056716  0.041791
# 2019-11-30 1008             1.0  0.023810  0.038690  0.043651  0.054563
# 2019-12-01 1008             1.0  0.020833  0.030754  0.040675  0.044643
# 2019-12-02 1011             1.0  0.026706  0.050445  0.041543  0.050445
# ...                         ...       ...       ...       ...       ...
# 2020-09-19 1634             1.0  0.018360  0.035496  0.047124  0.034884
# 2020-09-20 1636             1.0  0.024450  0.043399  0.023839       NaN
# 2020-09-21 1638             1.0  0.018926  0.029915       NaN       NaN
# 2020-09-22 1641             1.0  0.008531       NaN       NaN       NaN
# 2020-09-23 1048             1.0       NaN       NaN       NaN       NaN
#
# days_diff                        5         6         7         8         9    \
# reg_date   uid_cohort_size
# 2019-11-28 1004             0.067729  0.064741  0.041833  0.047809  0.048805
# 2019-11-29 1005             0.060697  0.066667  0.058706  0.055721  0.058706
# 2019-11-30 1008             0.072421  0.077381  0.047619  0.051587  0.053571
# 2019-12-01 1008             0.072421  0.070437  0.060516  0.050595  0.047619
# 2019-12-02 1011             0.059347  0.062315  0.066271  0.050445  0.051434
# ...                              ...       ...       ...       ...       ...
# 2020-09-19 1634                  NaN       NaN       NaN       NaN       NaN
# 2020-09-20 1636                  NaN       NaN       NaN       NaN       NaN
# 2020-09-21 1638                  NaN       NaN       NaN       NaN       NaN
# 2020-09-22 1641                  NaN       NaN       NaN       NaN       NaN
# 2020-09-23 1048                  NaN       NaN       NaN       NaN       NaN
#
# days_diff                   ...       291       292       293       294  \
# reg_date   uid_cohort_size  ...
# 2019-11-28 1004             ...  0.012948  0.011952  0.011952  0.006972
# 2019-11-29 1005             ...  0.011940  0.010945  0.011940  0.011940
# 2019-11-30 1008             ...  0.010913  0.014881  0.011905  0.012897
# 2019-12-01 1008             ...  0.014881  0.010913  0.011905  0.012897
# 2019-12-02 1011             ...  0.010880  0.009891  0.009891  0.010880
# ...                         ...       ...       ...       ...       ...
# 2020-09-19 1634             ...       NaN       NaN       NaN       NaN
# 2020-09-20 1636             ...       NaN       NaN       NaN       NaN
# 2020-09-21 1638             ...       NaN       NaN       NaN       NaN
# 2020-09-22 1641             ...       NaN       NaN       NaN       NaN
# 2020-09-23 1048             ...       NaN       NaN       NaN       NaN
#
# days_diff                        295       296       297       298       299  \
# reg_date   uid_cohort_size
# 2019-11-28 1004             0.007968  0.008964  0.020916  0.011952  0.012948
# 2019-11-29 1005             0.009950  0.017910  0.013930  0.008955  0.004975
# 2019-11-30 1008             0.011905  0.010913  0.009921  0.006944       NaN
# 2019-12-01 1008             0.012897  0.010913  0.003968       NaN       NaN
# 2019-12-02 1011             0.015826  0.008902       NaN       NaN       NaN
# ...                              ...       ...       ...       ...       ...
# 2020-09-19 1634                  NaN       NaN       NaN       NaN       NaN
# 2020-09-20 1636                  NaN       NaN       NaN       NaN       NaN
# 2020-09-21 1638                  NaN       NaN       NaN       NaN       NaN
# 2020-09-22 1641                  NaN       NaN       NaN       NaN       NaN
# 2020-09-23 1048                  NaN       NaN       NaN       NaN       NaN
#
# days_diff                        300
# reg_date   uid_cohort_size
# 2019-11-28 1004             0.003984
# 2019-11-29 1005                  NaN
# 2019-11-30 1008                  NaN
# 2019-12-01 1008                  NaN
# 2019-12-02 1011                  NaN
# ...                              ...
# 2020-09-19 1634                  NaN
# 2020-09-20 1636                  NaN
# 2020-09-21 1638                  NaN
# 2020-09-22 1641                  NaN
# 2020-09-23 1048                  NaN
#
# [301 rows x 301 columns]

# %% [markdown]
# <li>Теперь осталось запаковать действия, которые мы проделали выше, в функцию. Немного модифицируем алгоритм, чтобы можно было отфильтровать данные за определенный период.</li>

# %%
def get_cohort(period_from = '', period_to=''):
    #загружаем библиотеки
    import pandas as pd
    from datetime import timedelta
    
    #загружаем таблицы в переменные
    df_auth_data = pd.read_csv('auth_data.csv', sep=';')
    df_reg_data = pd.read_csv('reg_data.csv', sep=';')
            
    #преобразуем параметры в тип даты
    period_from = pd.to_datetime(period_from)
    period_to = pd.to_datetime(period_to)
    
    #Замечание по поводу применения pd.to_datetime(pd.to_datetime(...))
    #вложенный метод "to_datetime" приводит к типу object, 
    #а второй метод "to_datetime" уже приводит к типу "datetime64"
    df_auth_data['auth_ts'] = pd.to_datetime(pd.to_datetime(df_auth_data['auth_ts'], unit='s').dt.date)
    df_reg_data['reg_ts'] = pd.to_datetime(pd.to_datetime(df_reg_data['reg_ts'], unit='s').dt.date)

    #отфильтровываем необходимый период
    df_auth_data = df_auth_data.query('auth_ts >= @period_from and auth_ts <= @period_to')
    df_reg_data = df_reg_data.query('reg_ts >= @period_from and reg_ts <= @period_to')
    
    #Объединим таблицы вместе
    df_merged = df_reg_data.merge(df_auth_data, on='uid', how='left')
    
    #создадим колонку с разницей в днях между датой регистрации и датой авторизации
    df_merged['days_diff'] = (df_merged["auth_ts"] - df_merged["reg_ts"]).dt.days
    
    #сгруппируем ДФ по дате регистрации и разнице дней, чтобы сосчитать количество пользователей
    cohort_df = df_merged.groupby(['reg_ts', 'days_diff'], as_index=False)\
                        .agg({'uid' : 'nunique'})\
                        .rename(columns={'uid' : 'uid_count', 'reg_ts' : 'reg_date'})
    
    #создадим колонку размера когорты из нулевого дня, чтобы высчитать процент по каждому дню
    cohort_group_size = cohort_df.query('days_diff == 0')\
                                    .rename(columns={'uid_count' : 'uid_cohort_size'})\
                                    [['reg_date', 'uid_cohort_size']]

    #присоединяем колонку размера когорты к таблице
    cohort_df = cohort_df.merge(cohort_group_size, how='inner', on='reg_date')

    #считаем процент вернувшихся пользователей
    cohort_df['uid_retention_percent'] = cohort_df.uid_count / cohort_df.uid_cohort_size
    
    #преобразуем таблицу в вид сводной таблицы
    cohort_df = cohort_df.assign(reg_date = cohort_df.reg_date.dt.strftime('%Y-%m-%d'))
    cohort_df = cohort_df.pivot(index=['reg_date', 'uid_cohort_size'], columns = 'days_diff', values = 'uid_retention_percent')
    
    #задем стиль таблицы
    ur_style = (cohort_df
                .style
                .set_caption('ВНИМАНИЕ: ЕСЛИ ТАБЛИЦА НЕ ПОКРАСИЛАСЬ В ЦВЕТА, ТО НУЖНО ПЕРЕЧИТАТЬ НОУТБУК')  # добавляем подпись
                .background_gradient(cmap='viridis')  # раскрашиваем ячейки по столбцам
                .highlight_null('white')  # делаем белый фон для значений NaN
                .format("{:.2%}", na_rep=""))  # числа форматируем как проценты, NaN заменяем на пустоту

    return ur_style

# %%
get_cohort(period_from = '2020-08-01', period_to='2020-08-15')
# Out:
# <style type="text/css">
# #T_08164_row0_col0, #T_08164_row0_col13, #T_08164_row0_col14, #T_08164_row1_col0, #T_08164_row1_col4, #T_08164_row1_col12, #T_08164_row2_col0, #T_08164_row2_col11, #T_08164_row3_col0, #T_08164_row3_col7, #T_08164_row3_col9, #T_08164_row4_col0, #T_08164_row4_col5, #T_08164_row4_col8, #T_08164_row4_col10, #T_08164_row5_col0, #T_08164_row6_col0, #T_08164_row6_col2, #T_08164_row7_col0, #T_08164_row8_col0, #T_08164_row8_col6, #T_08164_row9_col0, #T_08164_row10_col0, #T_08164_row11_col0, #T_08164_row11_col3, #T_08164_row12_col0, #T_08164_row13_col0, #T_08164_row13_col1, #T_08164_row14_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_08164_row0_col1 {
#   background-color: #228d8d;
#   color: #f1f1f1;
# }
# #T_08164_row0_col2 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_08164_row0_col3 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_08164_row0_col4 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# #T_08164_row0_col5 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_08164_row0_col6, #T_08164_row9_col3 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_08164_row0_col7, #T_08164_row0_col9, #T_08164_row0_col12, #T_08164_row1_col1, #T_08164_row1_col10, #T_08164_row1_col13, #T_08164_row3_col11, #T_08164_row4_col6, #T_08164_row5_col2, #T_08164_row5_col3, #T_08164_row6_col8, #T_08164_row8_col5, #T_08164_row10_col4 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_08164_row0_col8, #T_08164_row5_col1 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_08164_row0_col10 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_08164_row0_col11, #T_08164_row4_col9 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_08164_row1_col2 {
#   background-color: #228c8d;
#   color: #f1f1f1;
# }
# #T_08164_row1_col3 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_08164_row1_col5 {
#   background-color: #48c16e;
#   color: #f1f1f1;
# }
# #T_08164_row1_col6, #T_08164_row3_col8 {
#   background-color: #3e4c8a;
#   color: #f1f1f1;
# }
# #T_08164_row1_col7 {
#   background-color: #4ec36b;
#   color: #000000;
# }
# #T_08164_row1_col8 {
#   background-color: #32648e;
#   color: #f1f1f1;
# }
# #T_08164_row1_col9 {
#   background-color: #2d708e;
#   color: #f1f1f1;
# }
# #T_08164_row1_col11 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_08164_row1_col14, #T_08164_row2_col14, #T_08164_row3_col14, #T_08164_row4_col14, #T_08164_row5_col14, #T_08164_row6_col14, #T_08164_row7_col14, #T_08164_row8_col14, #T_08164_row9_col14, #T_08164_row10_col14, #T_08164_row11_col14, #T_08164_row12_col14, #T_08164_row13_col14, #T_08164_row14_col14 {
#   background-color: #440154;
#   color: #f1f1f1;
#   background-color: white;
# }
# #T_08164_row2_col1, #T_08164_row5_col5 {
#   background-color: #31668e;
#   color: #f1f1f1;
# }
# #T_08164_row2_col2 {
#   background-color: #25ab82;
#   color: #f1f1f1;
# }
# #T_08164_row2_col3 {
#   background-color: #38598c;
#   color: #f1f1f1;
# }
# #T_08164_row2_col4 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_08164_row2_col5, #T_08164_row8_col3 {
#   background-color: #1f998a;
#   color: #f1f1f1;
# }
# #T_08164_row2_col6, #T_08164_row6_col7 {
#   background-color: #95d840;
#   color: #000000;
# }
# #T_08164_row2_col7 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_08164_row2_col8, #T_08164_row5_col6 {
#   background-color: #86d549;
#   color: #000000;
# }
# #T_08164_row2_col9, #T_08164_row3_col6 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_08164_row2_col10 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_08164_row2_col12 {
#   background-color: #73d056;
#   color: #000000;
# }
# #T_08164_row2_col13, #T_08164_row3_col12, #T_08164_row3_col13, #T_08164_row4_col11, #T_08164_row4_col12, #T_08164_row4_col13, #T_08164_row5_col10, #T_08164_row5_col11, #T_08164_row5_col12, #T_08164_row5_col13, #T_08164_row6_col9, #T_08164_row6_col10, #T_08164_row6_col11, #T_08164_row6_col12, #T_08164_row6_col13, #T_08164_row7_col8, #T_08164_row7_col9, #T_08164_row7_col10, #T_08164_row7_col11, #T_08164_row7_col12, #T_08164_row7_col13, #T_08164_row8_col7, #T_08164_row8_col8, #T_08164_row8_col9, #T_08164_row8_col10, #T_08164_row8_col11, #T_08164_row8_col12, #T_08164_row8_col13, #T_08164_row9_col6, #T_08164_row9_col7, #T_08164_row9_col8, #T_08164_row9_col9, #T_08164_row9_col10, #T_08164_row9_col11, #T_08164_row9_col12, #T_08164_row9_col13, #T_08164_row10_col5, #T_08164_row10_col6, #T_08164_row10_col7, #T_08164_row10_col8, #T_08164_row10_col9, #T_08164_row10_col10, #T_08164_row10_col11, #T_08164_row10_col12, #T_08164_row10_col13, #T_08164_row11_col4, #T_08164_row11_col5, #T_08164_row11_col6, #T_08164_row11_col7, #T_08164_row11_col8, #T_08164_row11_col9, #T_08164_row11_col10, #T_08164_row11_col11, #T_08164_row11_col12, #T_08164_row11_col13, #T_08164_row12_col3, #T_08164_row12_col4, #T_08164_row12_col5, #T_08164_row12_col6, #T_08164_row12_col7, #T_08164_row12_col8, #T_08164_row12_col9, #T_08164_row12_col10, #T_08164_row12_col11, #T_08164_row12_col12, #T_08164_row12_col13, #T_08164_row13_col2, #T_08164_row13_col3, #T_08164_row13_col4, #T_08164_row13_col5, #T_08164_row13_col6, #T_08164_row13_col7, #T_08164_row13_col8, #T_08164_row13_col9, #T_08164_row13_col10, #T_08164_row13_col11, #T_08164_row13_col12, #T_08164_row13_col13, #T_08164_row14_col1, #T_08164_row14_col2, #T_08164_row14_col3, #T_08164_row14_col4, #T_08164_row14_col5, #T_08164_row14_col6, #T_08164_row14_col7, #T_08164_row14_col8, #T_08164_row14_col9, #T_08164_row14_col10, #T_08164_row14_col11, #T_08164_row14_col12, #T_08164_row14_col13 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
# }
# #T_08164_row3_col1 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_08164_row3_col2 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_08164_row3_col3 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_08164_row3_col4 {
#   background-color: #48186a;
#   color: #f1f1f1;
# }
# #T_08164_row3_col5 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_08164_row3_col10, #T_08164_row11_col1 {
#   background-color: #4ac16d;
#   color: #000000;
# }
# #T_08164_row4_col1 {
#   background-color: #f8e621;
#   color: #000000;
# }
# #T_08164_row4_col2 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_08164_row4_col3 {
#   background-color: #38588c;
#   color: #f1f1f1;
# }
# #T_08164_row4_col4 {
#   background-color: #54c568;
#   color: #000000;
# }
# #T_08164_row4_col7 {
#   background-color: #7cd250;
#   color: #000000;
# }
# #T_08164_row5_col4 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_08164_row5_col7 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_08164_row5_col8 {
#   background-color: #a5db36;
#   color: #000000;
# }
# #T_08164_row5_col9 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_08164_row6_col1 {
#   background-color: #3aba76;
#   color: #f1f1f1;
# }
# #T_08164_row6_col3 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_08164_row6_col4 {
#   background-color: #414287;
#   color: #f1f1f1;
# }
# #T_08164_row6_col5 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_08164_row6_col6 {
#   background-color: #21a585;
#   color: #f1f1f1;
# }
# #T_08164_row7_col1 {
#   background-color: #addc30;
#   color: #000000;
# }
# #T_08164_row7_col2 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_08164_row7_col3 {
#   background-color: #2f6b8e;
#   color: #f1f1f1;
# }
# #T_08164_row7_col4 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_08164_row7_col5 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_08164_row7_col6 {
#   background-color: #27ad81;
#   color: #f1f1f1;
# }
# #T_08164_row7_col7 {
#   background-color: #dae319;
#   color: #000000;
# }
# #T_08164_row8_col1 {
#   background-color: #26ad81;
#   color: #f1f1f1;
# }
# #T_08164_row8_col2 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_08164_row8_col4 {
#   background-color: #3a548c;
#   color: #f1f1f1;
# }
# #T_08164_row9_col1 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_08164_row9_col2 {
#   background-color: #460a5d;
#   color: #f1f1f1;
# }
# #T_08164_row9_col4 {
#   background-color: #d2e21b;
#   color: #000000;
# }
# #T_08164_row9_col5 {
#   background-color: #23a983;
#   color: #f1f1f1;
# }
# #T_08164_row10_col1 {
#   background-color: #24878e;
#   color: #f1f1f1;
# }
# #T_08164_row10_col2 {
#   bac
